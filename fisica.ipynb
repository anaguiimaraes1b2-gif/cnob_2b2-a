# %% [markdown]
# <a href="https://colab.research.google.com/github/anaguiimaraes1b2-gif/cnob_2b2-a/blob/main/fisica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Fórmula da velocidade

# %%
def calculaVelMedia(deltaS, deltaT):
  velMedia = (deltaS/deltaT)
  return velMedia

# %% [markdown]
# ##Teste Serviço Nuvem: Velocidade Média

# %%
print("Vm=", calculaVelMedia(30, 15))
# Out:
# Vm= 2.0

# %% [markdown]
# ##Fórmula da aceleração

# %%
def calculaVelMedia(deltaV, deltaS):
  velMedia = (deltaV/deltaS)
  return velMedia

# %%
print("Am=", calculaVelMedida(84, 7))

# %% [markdown]
#  ## função do deslocamento

# %%
def calculaDesloc(inicialS, deltaT, v):
  d = inicialS + (v*deltaT)
  return d

# %%
print("Deslocamento= ",calculaDesloc(0, 15, 30))

# %% [markdown]
# #Fórmulas do Movimento Uniformemente Variado (MUV)
